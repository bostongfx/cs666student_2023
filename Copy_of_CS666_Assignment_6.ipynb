# %% [markdown]
# <a href="https://colab.research.google.com/github/varshi-123/cs666student/blob/main/Copy_of_CS666_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](data:image/png;base64,...)
# # Assignment 6

# %%
# NAME:

# %%
# In this assignment, we will explore the new Segment-Anything-Model (https://segment-anything.com/)
# for the task of mitochondria detection in a connectomics dataset acquired using electron microscopy.
#
# We will run the following experiments:
#
# 1. Using the Segment-Anything-Model (SAM) without seeds in auto mode
#
# 2. Train a U-Net classifier from scratch
#
# 3. Evaluate the U-Net classifier
#
# 4. Use the U-Net to seed the SAM model (U-Net + SAM)
#
# 5. Compare U-Net vs. U-Net + SAM
#
# Bonus: Improve U-Net + SAM

# %%
### IMPORTANT (DO THIS RIGHT AWAY!) ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# We will use mahotas as well!
# !pip install mahotas --no-binary :all:
import mahotas as mh
# Out:
# DEPRECATION: --no-binary currently disables reading from the cache of locally built wheels. In the future --no-binary will not influence the wheel cache. pip 23.1 will enforce this behaviour change. A possible replacement is to use the --no-cache-dir option. You can use the flag --use-feature=no-binary-enable-wheel-cache to test the upcoming behaviour. Discussion can be found at https://github.com/pypa/pip/issues/11453
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mahotas
#   Downloading mahotas-1.4.13.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 16.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mahotas) (1.22.4)
# Installing collected packages: mahotas
#   DEPRECATION: mahotas is being installed using the legacy 'setup.py install' method, because the '--no-binary' option was enabled for it and this currently disables local wheel building for projects that don't have a 'pyproject.toml' file. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/11451
#   Running setup.py install for mahotas ... done
# Successfully installed mahotas-1.4.13

# %%
# And of course, we need the data!
# !wget https://cs666.org/data/mito.npz
# Out:
# --2023-04-25 01:33:41--  https://cs666.org/data/mito.npz
# Resolving cs666.org (cs666.org)... 185.199.110.153, 185.199.111.153, 185.199.108.153, ...
# Connecting to cs666.org (cs666.org)|185.199.110.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37610178 (36M) [application/octet-stream]
# Saving to: ‘mito.npz’
#
# mito.npz            100%[===================>]  35.87M   155MB/s    in 0.2s
#
# 2023-04-25 01:33:42 (155 MB/s) - ‘mito.npz’ saved [37610178/37610178]

# %% [markdown]
# ## 0. Data loading (5 points)

# %%
# The data includes images and manually segmented masks.
loaded = np.load('mito.npz')
images = loaded['arr_0'][0]
masks = loaded['arr_0'][1]

# %%
# TODO: Show the first image with the gray colormap.
# TODO: YOUR_CODE
import matplotlib.pyplot as plt
plt.imshow(images[0], cmap='gray')
plt.show()

# %%
# TODO: Show the first mask.
import matplotlib.pyplot as plt

plt.imshow(masks[0], cmap='gray')
plt.show()

# %% [markdown]
# ## 1. SAM in AUTO mode (15 points)

# %%
# We will use the METASEG package as an easy-to-use layer
# for SAM.
# !pip install metaseg
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting metaseg
#   Downloading metaseg-0.7.0.tar.gz (38 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: torchvision>=0.8 in /usr/local/lib/python3.9/dist-packages (from metaseg) (0.15.1+cu118)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from metaseg) (4.65.0)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.9/dist-packages (from metaseg) (2.0.0+cu118)
# Requirement already satisfied: pillow in /usr/local/lib/python3.9/dist-packages (from metaseg) (8.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from metaseg) (3.7.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from metaseg) (4.7.0.72)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.9/dist-packages (from metaseg) (2.0.6)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg) (1.11.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg) (3.11.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg) (2.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg) (4.5.0)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->metaseg) (16.0.1)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->metaseg) (3.25.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.8->metaseg) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.8->metaseg) (2.27.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (1.0.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (23.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (3.0.9)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (5.12.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (1.4.4)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg) (0.11.0)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->metaseg) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->metaseg) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.7->metaseg) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg) (2022.12.7)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7->metaseg) (1.3.0)
# Building wheels for collected packages: metaseg
#   Building wheel for metaseg (pyproject.toml) ... done
#   Created wheel for metaseg: filename=metaseg-0.7.0-py3-none-any.whl size=45787 sha256=7e3e76eec3ebb4d4f040a7762cb1b8316fdf42286e3504580518e3671e4f5dda
#   Stored in directory: /root/.cache/pip/wheels/3f/3f/89/039a62d4b580e94d8d678cc5b91dd4adffab3c0e78d11f0deb
# Successfully built metaseg
# Installing collected packages: metaseg
# Successfully installed metaseg-0.7.0

# %%
 # SAM comes in two modes, auto and with seeds
from metaseg import SegAutoMaskPredictor, SegManualMaskPredictor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-24-3e3a8a617596> in <cell line: 2>()
#       1 # SAM comes in two modes, auto and with seeds
# ----> 2 from metaseg import SegAutoMaskPredictor, SegManualMaskPredictor
#
# /usr/local/lib/python3.9/dist-packages/metaseg/__init__.py in <module>
#       5 # LICENSE file in the root directory of this source tree.
#       6
# ----> 7 from metaseg.falai_demo import falai_automask_image, falai_manuelmask_image
#       8 from metaseg.generator.automatic_mask_generator import SamAutomaticMaskGenerator
#       9 from metaseg.generator.build_sam import build_sam, build_sam_vit_b, build_sam_vit_h, build_sam_vit_l, sam_model_registry
#
# /usr/local/lib/python3.9/dist-packages/metaseg/falai_demo.py in <module>
#       3 from PIL import Image
#       4
# ----> 5 from metaseg import SegAutoMaskPredictor, SegManualMaskPredictor
#       6 from metaseg.utils.data_utils import load_server_image
#       7
#
# ImportError: cannot import name 'SegAutoMaskPredictor' from partially initialized module 'metaseg' (most likely due to a circular import) (/usr/local/lib/python3.9/dist-packages/metaseg/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# SAM takes files as input!
# So we have to store the numpy array to disk.
mh.imsave('first.png', images[0])

# %%
#
# Run SAM in auto mode on first.png and store
# the result as first_output.png.
#
results = SegAutoMaskPredictor().image_predict(
    source="first.png",
    model_type="vit_l", # vit_l, vit_h, vit_b
    points_per_side=16, 
    points_per_batch=64,
    min_area=0,
    output_path="first_output.png",
    show=False,
    save=True,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-266b25163fad> in <cell line: 5>()
#       3 # the result as first_output.png.
#       4 #
# ----> 5 results = SegAutoMaskPredictor().image_predict(
#       6     source="first.png",
#       7     model_type="vit_l", # vit_l, vit_h, vit_b
#
# NameError: name 'SegAutoMaskPredictor' is not defined

# %%
imshow( mh.imread('first_output.png') )

# %%
# TODO: Does SAM work well for mitochondria detection?
# TODO: YOUR_ANSWER

# %%
# TODO: Try the auto predictor on your image!
# 
# Please upload your own image and test how well
# the auto mode of SAM performs!
#
# Run SAM in auto mode on that image and store
# the result as second_output.png. Show the output!
#

# %%
# TODO: YOUR CODE

# %%
# TODO: Does SAM work well on your example?
# TODO: YOUR_ANSWER

# %% [markdown]
# ## 2. Train a U-Net classifier from scratch (50 points)

# %%
# We will use the keras_unet package!
#
# HINT: There is documentation available here, if you are stuck during this part
# of the assignment: https://github.com/karolzak/keras-unet
# !pip install keras_unet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting keras_unet
#   Downloading keras_unet-0.1.2-py3-none-any.whl (16 kB)
# Installing collected packages: keras_unet
# Successfully installed keras_unet-0.1.2

# %%
# keras_unet has convenience functions to visualize data
from keras_unet.utils import plot_imgs
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %%
# Let's plot a few images and masks.
plot_imgs(org_imgs=images, mask_imgs=masks)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# The images are in this format.
print( images.shape, images.max(), images.dtype )
# Out:
# (660, 256, 256) 243 uint8

# %%
# TODO convert the format to the following:
# (660, 256, 256, 1) 1.0 float32
#
# 1) convert to float32
# 2) normalize to the range of 0..1
# 3) Add the last channel using .reshape like in class
#
# TODO: YOUR_CODE
# X =
X = images.astype(np.float32) / 255.0
X = np.expand_dims(X, axis=-1)

# Check the resulting shape, max value, and dtype
print(X.shape, X.max(), X.dtype)
# Out:
# (660, 256, 256, 1) 0.9529412 float32

# %%
# Validate that everything matches accordingly
print( X.shape, X.max(), X.dtype )
# Out:
# (660, 256, 256, 1) 0.9529412 float32

# %%
# The masks are in this format.
print( masks.shape, masks.max(), masks.dtype )
# Out:
# (660, 256, 256) 255 uint8

# %%
# TODO convert the format to the following:
# (660, 256, 256, 1) True bool
#
# 1) convert to bool
# 2) Add the last channel using .reshape like in class
#
# TODO: YOUR_CODE
# y = y = masks.astype(bool) 
y = (masks > 0.5).astype(np.bool)

# Add the last channel using np.expand_dims()
y = np.expand_dims(y, axis=-1)

# Check the resulting shape and dtype
print(y.shape, y.dtype)
# Out:
# (660, 256, 256, 1) bool
# <ipython-input-32-c3dd89813084>:9: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   y = (masks > 0.5).astype(np.bool)

# %%
# Validate that everything matches accordingly
print( y.shape, y.max(), y.dtype )
# Out:
# (660, 256, 256, 1) True bool

# %%
#
# Now we will create our train/val/test splits using scikit-learn!
#
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %%
print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_val: ", X_val.shape)
print("y_val: ", y_val.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)
# Out:
# X_train:  (369, 256, 256, 1)
# y_train:  (369, 256, 256, 1)
# X_val:  (159, 256, 256, 1)
# y_val:  (159, 256, 256, 1)
# X_test:  (132, 256, 256, 1)
# y_test:  (132, 256, 256, 1)

# %%
# TODO: Why do we call train_test_split twice?
# TODO: YOUR_ANSWER

# %% [markdown]
# To construct three unique datasets for training, validation, and testing, we utilize the train_test_split function twice.
#  we split the data into training (80%) and testing (20%) sets using the test_size parameter.
#  we split the training set into a smaller training set and a validation set  using the test_size parameter again.
#  The training data constitutes 56% of the total data,
# the validation data constitutes 24% of the total data,
# the testing data constitutes 20% of the total data.

# %%
#
# We will use keras_unet's built-in data augmentation
# functionality.
#
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    X_train, y_train, batch_size=2,
    data_gen_args = dict(
        rotation_range=15.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=50,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %%
# TODO: Please explain the code from above.
# TODO: YOUR_ANSWER

# %% [markdown]
# The code above is using the get_augmented function from the keras_unet.
# get_augmented takes three arguments: X_train, y_train, and batch_size.
# The rotation_range parameter specifies the range (in degrees) for randomly rotating the images.
# The width_shift_range and height_shift_range parameters specify the range (as a fraction of the image size) for randomly shifting the images horizontally and vertically.
#  The shear_range parameter specifies the range (in degrees) for randomly shearing the images.
#  The zoom_range parameter specifies the range for randomly zooming the images.
#  The horizontal_flip and vertical_flip parameters specify whether or not to randomly flip the images horizontally or vertically.
#  The fill_mode parameter specifies the strategy for filling in newly created pixels after transformations (such as rotation or shifting).
# The output of get_augmented is an augmented image data generator that can be used for training a U-Net model using the fit_generator method of a Keras model.

# %%
# Run the following code to visualize augmented examples.
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy, nm_img_to_plot=2, figsize=6)
# Out:
# (2, 256, 256, 1) (2, 256, 256, 1)

# %%
#
# Now, we set up a U-Net classifier.
#
from keras_unet.models import custom_unet

model = custom_unet(
    X_train[0].shape,
    use_batch_norm=False,
    num_classes=1,
    filters=64,
    dropout=0.2,
    output_activation='sigmoid'
)

# %%
# TODO: How many  trainable parameters does the model use?
# TODO: YOUR_ANSWER
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 256, 256, 64  640         ['input_1[0][0]']
#                                 )
#
#  spatial_dropout2d (SpatialDrop  (None, 256, 256, 64  0          ['conv2d[0][0]']
#  out2D)                         )
#
#  conv2d_1 (Conv2D)              (None, 256, 256, 64  36928       ['spatial_dropout2d[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 128, 128, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 128, 128, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  spatial_dropout2d_1 (SpatialDr  (None, 128, 128, 12  0          ['conv2d_2[0][0]']
#  opout2D)                       8)
#
#  conv2d_3 (Conv2D)              (None, 128, 128, 12  147584      ['spatial_dropout2d_1[0][0]']
#                                 8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_3[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 64, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  spatial_dropout2d_2 (SpatialDr  (None, 64, 64, 256)  0          ['conv2d_4[0][0]']
#  opout2D)
#
#  conv2d_5 (Conv2D)              (None, 64, 64, 256)  590080      ['spatial_dropout2d_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_5[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 32, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  spatial_dropout2d_3 (SpatialDr  (None, 32, 32, 512)  0          ['conv2d_6[0][0]']
#  opout2D)
#
#  conv2d_7 (Conv2D)              (None, 32, 32, 512)  2359808     ['spatial_dropout2d_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0          ['conv2d_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  spatial_dropout2d_4 (SpatialDr  (None, 16, 16, 1024  0          ['conv2d_8[0][0]']
#  opout2D)                       )
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 1024  9438208     ['spatial_dropout2d_4[0][0]']
#                                 )
#
#  conv2d_transpose (Conv2DTransp  (None, 32, 32, 512)  2097664    ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 32, 32, 1024  0           ['conv2d_transpose[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_10[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 256)  524544     ['conv2d_11[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_12[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 12  131200     ['conv2d_13[0][0]']
#  spose)                         8)
#
#  concatenate_2 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_2[0][0]',
#                                 6)                                'conv2d_3[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_2[0][0]']
#                                 8)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_14[0][0]']
#                                 8)
#
#  conv2d_transpose_3 (Conv2DTran  (None, 256, 256, 64  32832      ['conv2d_15[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_3[0][0]',
#                                 8)                                'conv2d_1[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_16[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 1)  65          ['conv2d_17[0][0]']
#
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
#
# Let's compile the model. Please use a LEARNING_RATE of 0.01
# and a MOMENTUM of 0.99.
#
LEARNING_RATE = 0.01
MOMENTUM = 0.99

# %%
#
# We will use Stochastic Gradient Descent as optimizer
# and use IoU as a metric.
#
from keras.optimizers import SGD
from keras_unet.metrics import iou, iou_thresholded

model.compile(
    optimizer=SGD(learning_rate=LEARNING_RATE, momentum=MOMENTUM),
    loss='binary_crossentropy',
    metrics=[iou, iou_thresholded]
)

# %%
# TODO: Please explain Intersect-over-Union (IoU) in just a few sentences.
# TODO: YOUR_ANSWER

# %% [markdown]
# Intersection-over-Union (IoU) is a metric used to evaluate the performance of object detection and segmentation algorithms.
#  It measures the overlap between the predicted bounding box.
#  The higher the IoU score, the better the performance of the algorithm in accurately localizing the object.

# %%
#
# Now let's train the model for 30 epochs!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use the train_gen from above as training data.
# Hint 2: Please don't forget (X_val, y_val) as validation data.
# Hint 3: steps_per_epoch should be set to all of the X_train.
# Hint 4: This will take roughly 30 minutes.
# Hint 5: If you are stuck, look through the repo of keras_unet!
#
batch_size = 2
epochs = 30

history = model.fit_generator(
    train_gen,
    steps_per_epoch=len(X_train) // batch_size,
    epochs=epochs,
    validation_data=(X_val, y_val),
    shuffle=True
)
# Out:
# <ipython-input-44-7cc292a5b8d0>:14: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/30
# 184/184 [==============================] - 3117s 17s/step - loss: 0.2581 - iou: 0.0401 - iou_thresholded: 2.3983e-04 - val_loss: 0.2242 - val_iou: 0.0687 - val_iou_thresholded: 6.0699e-06
# Epoch 2/30
#  15/184 [=>............................] - ETA: 41:47 - loss: 0.2046 - iou: 0.0721 - iou_thresholded: 1.2935e-04
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-44-7cc292a5b8d0> in <cell line: 14>()
#      12 epochs = 30
#      13
# ---> 14 history = model.fit_generator(
#      15     train_gen,
#      16     steps_per_epoch=len(X_train) // batch_size,
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    2634             stacklevel=2,
#    2635         )
# -> 2636         return self.fit(
#    2637             generator,
#    2638             steps_per_epoch=steps_per_epoch,
#
# /usr/local/lib/python3.9/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
#      66         except Exception as e:
#      67             filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1683                         ):
#    1684                             callbacks.on_train_batch_begin(step)
# -> 1685                             tmp_logs = self.train_function(iterator)
#    1686                             if data_handler.should_sync:
#    1687                                 context.async_wait()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/util/traceback_utils.py in error_handler(*args, **kwargs)
#     148     filtered_tb = None
#     149     try:
# --> 150       return fn(*args, **kwargs)
#     151     except Exception as e:
#     152       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in __call__(self, *args, **kwds)
#     892
#     893       with OptionalXlaContext(self._jit_compile):
# --> 894         result = self._call(*args, **kwds)
#     895
#     896       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/polymorphic_function.py in _call(self, *args, **kwds)
#     924       # In this case we have created variables on the first call, so we run the
#     925       # defunned version which is guaranteed to never create variables.
# --> 926       return self._no_variable_creation_fn(*args, **kwds)  # pylint: disable=not-callable
#     927     elif self._variable_creation_fn is not None:
#     928       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/tracing_compiler.py in __call__(self, *args, **kwargs)
#     141       (concrete_function,
#     142        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# --> 143     return concrete_function._call_flat(
#     144         filtered_flat_args, captured_inputs=concrete_function.captured_inputs)  # pylint: disable=protected-access
#     145
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1755         and executing_eagerly):
#    1756       # No tape is watching; skip to running the function.
# -> 1757       return self._build_call_outputs(self._inference_function.call(
#    1758           ctx, args, cancellation_manager=cancellation_manager))
#    1759     forward_backward = self._select_forward_and_backward_functions(
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/polymorphic_function/monomorphic_function.py in call(self, ctx, args, cancellation_manager)
#     379       with _InterpolateFunctionError(self):
#     380         if cancellation_manager is None:
# --> 381           outputs = execute.execute(
#     382               str(self.signature.name),
#     383               num_outputs=self._num_outputs,
#
# /usr/local/lib/python3.9/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      50   try:
#      51     ctx.ensure_initialized()
# ---> 52     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      53                                         inputs, attrs, num_outputs)
#      54   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# We can use keras_unet functionality to visualize metrics and loss during training.
from keras_unet.utils import plot_segm_history

plot_segm_history(history)
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cb8a8160b1cf> in <cell line: 4>()
#       2 from keras_unet.utils import plot_segm_history
#       3
# ----> 4 plot_segm_history(history)
#
# NameError: name 'history' is not defined

# %%
# TODO: Do these plots look good to you?
# TODO: YOUR_ANSWER

# %% [markdown]
# Yes, the plots good for me because the IoU is incresing and the loss is decreasing for each epoch.

# %% [markdown]
# ## 3. Evaluate U-Net (10 points)

# %%
# Let's predict all of X_test
y_pred = model.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-18e47c1ee326> in <cell line: 2>()
#       1 # Let's predict all of X_test
# ----> 2 y_pred = model.predict(X_test)
#
# NameError: name 'model' is not defined

# %%
# ...and look at some results.
plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=9)

# %%
import sklearn.metrics

# %%
# Let's use the Jaccard score to compare a thresholded
# y_pred to the groundtruth y_test.
sklearn.metrics.jaccard_score(y_test.ravel(), (y_pred > 0.5).ravel())

# %%
# TODO: What is the difference between Jaccard Score and Intersect-over-Union from above?
# TODO: YOUR_ANSWER

# %%
# TODO: Did the U-Net perform well on X_test?
# TODO: YOUR_ANSWER

# %% [markdown]
# ## 4. Combine U-Net with SAM (10 points)

# %%
# Instead of running SAM in auto mode without seeds (Task 1), we will now
# use the U-Net predictions on X_test to seed the SAM model.

# %%
# We can use the following convenience functions
# to 1) convert mahotas bounding boxes to SAM format
# and 2) combine the SAM output tensors to a mask.

# %%
def mahotas_bbox_to_sam(bbs):

  new_bbs = []

  for i,bb in enumerate(bbs):
    # from (y1, y2, x1, x2)
    # to (x1, y1, x2, y2)
    if i == 0:
      continue
    new_bb = [bb[2], bb[0], bb[3], bb[1]]
    new_bbs.append(new_bb)

  return new_bbs

# %%
def sam_to_mask(results):

  results = results.cpu() # copy back to cpu land

  mask = np.array(results[0,0])

  for s in results:
    mask[s[0] == 1] = 1

  return mask

# %%
# The following code combines the U-Net predictions with SAM.
#
# TODO: Please study the code and answer the TODOs in-line.

# %%
y_pred_sam = y_pred.copy()
y_pred_sam[:] = 0

for z,img in enumerate(X_test):

  # TODO: EXPLAIN CODE BELOW
  mh.imsave('test.png', (img[:,:,0]*255).astype(np.uint8))

  # TODO: EXPLAIN CODE BELOW
  pred = (y_pred[z] > 0.5)

  # TODO: EXPLAIN CODE BELOW
  pred, _ = mh.labeled.label(pred)
  
  # TODO: EXPLAIN CODE BELOW
  bbs = mh.labeled.bbox(pred)

  # TODO: EXPLAIN CODE BELOW
  bbs_converted = mahotas_bbox_to_sam(bbs)

  # TODO: EXPLAIN CODE BELOW
  results = SegManualMaskPredictor().image_predict(
      source="test.png",
      model_type="vit_l", # vit_l, vit_h, vit_b
      input_box=bbs_converted, 
      multimask_output=False,
      random_color=False,
      show=False,
      save=False,
  )

  # TODO: EXPLAIN CODE BELOW
  sam_and_unet_pred = sam_to_mask(results)

  # TODO: EXPLAIN CODE BELOW
  y_pred_sam[z,:,:,0] = sam_and_unet_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-68419d2bfe36> in <cell line: 1>()
# ----> 1 y_pred_sam = y_pred.copy()
#       2 y_pred_sam[:] = 0
#       3
#       4 for z,img in enumerate(X_test):
#       5
#
# NameError: name 'y_pred' is not defined

# %% [markdown]
# The code is iterating through each image in the test set (X_test).
#  For each image, it is converting it to a binary mask using a threshold of 0.5 (pred = (y_pred[z] > 0.5)).
#   It is then labeling the connected regions in the mask (pred, _ = mh.labeled.label(pred)), and finding the bounding box of each connected region (bbs = mh.labeled.bbox(pred)).
#    These bounding boxes are then converted to a format expected by a segmentation model, and passed as input to the SegManualMaskPredictor().image_predict() function, which generates a segmentation prediction using a separate model trained on manually annotated masks.
#     Finally, the segmentation predictions from this model are combined with the predictions from the U-Net model (sam_and_unet_pred), and stored in y_pred_sam.

# %% [markdown]
# ## 5. Compare U-Net vs. U-Net+SAM. (10 points)

# %%
# U-Net performance on X_test (from Task 3)
sklearn.metrics.jaccard_score(y_test.ravel(), (y_pred > 0.5).ravel())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-70890a98cb00> in <cell line: 2>()
#       1 # U-Net performance on X_test (from Task 3)
# ----> 2 sklearn.metrics.jaccard_score(y_test.ravel(), (y_pred > 0.5).ravel())
#
# NameError: name 'sklearn' is not defined

# %%
# U-Net + SAM performance on X_test
sklearn.metrics.jaccard_score(y_test.ravel(), y_pred_sam.ravel())

# %%
# TODO: Please explain the results - is U-Net+SAM a good addition?
# TODO: YOUR_ANSWER

# %% [markdown]
# ## Bonus: Improve the results. (33 points)

# %%
# Please improve the results of U-Net+SAM and show the improved Jaccard score.

# %%
# TODO: YOUR_CODE

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
