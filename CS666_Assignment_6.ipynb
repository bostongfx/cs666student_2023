# %% [markdown]
# <a href="https://colab.research.google.com/github/Sairam-Bandarupalli/cs666student/blob/main/CS666_Assignment_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![logo.png](data:image/png;base64,...)
# # Assignment 6

# %%
# NAME: Sairam Bandarupalli

# %%
# In this assignment, we will explore the new Segment-Anything-Model (https://segment-anything.com/)
# for the task of mitochondria detection in a connectomics dataset acquired using electron microscopy.
#
# We will run the following experiments:
#
# 1. Using the Segment-Anything-Model (SAM) without seeds in auto mode
#
# 2. Train a U-Net classifier from scratch
#
# 3. Evaluate the U-Net classifier
#
# 4. Use the U-Net to seed the SAM model (U-Net + SAM)
#
# 5. Compare U-Net vs. U-Net + SAM
#
# Bonus: Improve U-Net + SAM

# %%
### IMPORTANT (DO THIS RIGHT AWAY!) ###
#
# Activate GPU support: Runtime -> Change Runtime Type
# Hardware Accelerator: GPU
#
### IMPORTANT ###

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
# We will use mahotas as well!
# !pip install mahotas --no-binary :all:
import mahotas as mh
# Out:
# DEPRECATION: --no-binary currently disables reading from the cache of locally built wheels. In the future --no-binary will not influence the wheel cache. pip 23.1 will enforce this behaviour change. A possible replacement is to use the --no-cache-dir option. You can use the flag --use-feature=no-binary-enable-wheel-cache to test the upcoming behaviour. Discussion can be found at https://github.com/pypa/pip/issues/11453
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting mahotas
#   Downloading mahotas-1.4.13.tar.gz (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 66.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from mahotas) (1.22.4)
# Installing collected packages: mahotas
#   DEPRECATION: mahotas is being installed using the legacy 'setup.py install' method, because the '--no-binary' option was enabled for it and this currently disables local wheel building for projects that don't have a 'pyproject.toml' file. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/11451
#   Running setup.py install for mahotas ... done
# Successfully installed mahotas-1.4.13

# %%
# And of course, we need the data!
# !wget https://cs666.org/data/mito.npz
# Out:
# --2023-04-25 00:46:02--  https://cs666.org/data/mito.npz
# Resolving cs666.org (cs666.org)... 185.199.110.153, 185.199.111.153, 185.199.108.153, ...
# Connecting to cs666.org (cs666.org)|185.199.110.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37610178 (36M) [application/octet-stream]
# Saving to: ‘mito.npz.2’
#
# mito.npz.2          100%[===================>]  35.87M  --.-KB/s    in 0.1s
#
# 2023-04-25 00:46:03 (354 MB/s) - ‘mito.npz.2’ saved [37610178/37610178]

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 0. Data loading (5 points)

# %%
# The data includes images and manually segmented masks.
loaded = np.load('mito.npz')
images = loaded['arr_0'][0]
masks = loaded['arr_0'][1]

# %%
# TODO: Show the first image with the gray colormap.
# TODO: YOUR_CODE

# %%
plt.imshow(images[0], cmap='gray')
plt.show()

# %%
# TODO: Show the first mask.
plt.imshow(masks[0], cmap='gray')
plt.show()

# %% [markdown]
# ## 1. SAM in AUTO mode (15 points)

# %%
# We will use the METASEG package as an easy-to-use layer
# for SAM.
# !pip install metaseg==0.6.1
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: metaseg==0.6.1 in /usr/local/lib/python3.9/dist-packages (0.6.1)
# Requirement already satisfied: black==21.7b0 in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (21.7b0)
# Requirement already satisfied: isort==5.9.2 in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (5.9.2)
# Requirement already satisfied: torchvision>=0.8 in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (0.15.1+cu118)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (4.7.0.72)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (2.0.0+cu118)
# Requirement already satisfied: pycocotools in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (2.0.6)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (3.7.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (4.65.0)
# Requirement already satisfied: flake8==3.9.2 in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (3.9.2)
# Requirement already satisfied: click==8.0.4 in /usr/local/lib/python3.9/dist-packages (from metaseg==0.6.1) (8.0.4)
# Requirement already satisfied: pathspec<1,>=0.8.1 in /usr/local/lib/python3.9/dist-packages (from black==21.7b0->metaseg==0.6.1) (0.11.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.9/dist-packages (from black==21.7b0->metaseg==0.6.1) (1.0.0)
# Requirement already satisfied: regex>=2020.1.8 in /usr/local/lib/python3.9/dist-packages (from black==21.7b0->metaseg==0.6.1) (2022.10.31)
# Requirement already satisfied: tomli<2.0.0,>=0.2.6 in /usr/local/lib/python3.9/dist-packages (from black==21.7b0->metaseg==0.6.1) (1.2.3)
# Requirement already satisfied: appdirs in /usr/local/lib/python3.9/dist-packages (from black==21.7b0->metaseg==0.6.1) (1.4.4)
# Requirement already satisfied: mccabe<0.7.0,>=0.6.0 in /usr/local/lib/python3.9/dist-packages (from flake8==3.9.2->metaseg==0.6.1) (0.6.1)
# Requirement already satisfied: pyflakes<2.4.0,>=2.3.0 in /usr/local/lib/python3.9/dist-packages (from flake8==3.9.2->metaseg==0.6.1) (2.3.1)
# Requirement already satisfied: pycodestyle<2.8.0,>=2.7.0 in /usr/local/lib/python3.9/dist-packages (from flake8==3.9.2->metaseg==0.6.1) (2.7.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg==0.6.1) (1.11.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg==0.6.1) (4.5.0)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg==0.6.1) (2.0.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg==0.6.1) (3.1.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg==0.6.1) (3.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from torch>=1.7->metaseg==0.6.1) (3.11.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->metaseg==0.6.1) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.7->metaseg==0.6.1) (16.0.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.8->metaseg==0.6.1) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.8->metaseg==0.6.1) (2.27.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision>=0.8->metaseg==0.6.1) (8.4.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (0.11.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (5.12.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (4.39.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (1.0.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (2.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.9/dist-packages (from matplotlib->metaseg==0.6.1) (23.1)
# Requirement already satisfied: zipp>=3.1.0 in /usr/local/lib/python3.9/dist-packages (from importlib-resources>=3.2.0->matplotlib->metaseg==0.6.1) (3.15.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.7->matplotlib->metaseg==0.6.1) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.7->metaseg==0.6.1) (2.1.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg==0.6.1) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg==0.6.1) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg==0.6.1) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->torchvision>=0.8->metaseg==0.6.1) (2.0.12)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.7->metaseg==0.6.1) (1.3.0)

# %%
# SAM comes in two modes, auto and with seeds
from metaseg import SegAutoMaskPredictor, SegManualMaskPredictor

# %%
# SAM takes files as input!
# So we have to store the numpy array to disk.
mh.imsave('first.png', images[0])

# %%
#
# Run SAM in auto mode on first.png and store
# the result as first_output.png.
#
results = SegAutoMaskPredictor().image_predict(
    source="first.png",
    model_type="vit_l", # vit_l, vit_h, vit_b
    points_per_side=16, 
    points_per_batch=64,
    min_area=0,
    output_path="first_output.png",
    show=False,
    save=True,
)
# Out:
# vit_l model already exists as 'vit_l.pth'. Skipping download.

# %%
imshow( mh.imread('first_output.png') )

# %%
# TODO: Does SAM work well for mitochondria detection?
# TODO: YOUR_ANSWER
# Yes it is working good.

# %%
# TODO: Try the auto predictor on your image!
# 
# Please upload your own image and test how well
# the auto mode of SAM performs!
#
# Run SAM in auto mode on that image and store
# the result as second_output.png. Show the output!
#

# %%
# TODO: YOUR CODE
results = SegAutoMaskPredictor().image_predict(
    source="1.png",
    model_type="vit_l", # vit_l, vit_h, vit_b
    points_per_side=16, 
    points_per_batch=64,
    min_area=0,
    output_path="2.png",
    show=False,
    save=True,
)
# Out:
# vit_l model already exists as 'vit_l.pth'. Skipping download.

# %%
# TODO: Does SAM work well on your example?
# TODO: YOUR_ANSWER
imshow( mh.imread('2.png') )

# %% [markdown]
# ## 2. Train a U-Net classifier from scratch (50 points)

# %%
# We will use the keras_unet package!
#
# HINT: There is documentation available here, if you are stuck during this part
# of the assignment: https://github.com/karolzak/keras-unet
# !pip install keras_unet
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: keras_unet in /usr/local/lib/python3.9/dist-packages (0.1.2)

# %%
# keras_unet has convenience functions to visualize data
from keras_unet.utils import plot_imgs

# %%
# Let's plot a few images and masks.
plot_imgs(org_imgs=images, mask_imgs=masks)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# The images are in this format.
print( images.shape, images.max(), images.dtype )
# Out:
# (660, 256, 256) 243 uint8

# %%
# TODO convert the format to the following:
# (660, 256, 256, 1) 1.0 float32
#
# 1) convert to float32
# 2) normalize to the range of 0..1
# 3) Add the last channel using .reshape like in class
#
# TODO: YOUR_CODE
# X = 
X = images.astype(np.float32)
X = (X - X.min()) / (X.max() - X.min())
X = X.reshape(*X.shape, 1)

# %%
# Validate that everything matches accordingly
print( X.shape, X.max(), X.dtype )
# Out:
# (660, 256, 256, 1) 1.0 float32

# %%
# The masks are in this format.
print( masks.shape, masks.max(), masks.dtype )
# Out:
# (660, 256, 256) 255 uint8

# %%
# TODO convert the format to the following:
# (660, 256, 256, 1) True bool
#
# 1) convert to bool
# 2) Add the last channel using .reshape like in class
#
# TODO: YOUR_CODE
# y = 
y = masks.astype(bool)
y = y.reshape(*y.shape, 1)

# %%
# Validate that everything matches accordingly
print( y.shape, y.max(), y.dtype )
# Out:
# (660, 256, 256, 1) True bool

# %%
#
# Now we will create our train/val/test splits using scikit-learn!
#
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.3, random_state=0)

# %%
print("X_train: ", X_train.shape)
print("y_train: ", y_train.shape)
print("X_val: ", X_val.shape)
print("y_val: ", y_val.shape)
print("X_test: ", X_test.shape)
print("y_test: ", y_test.shape)
# Out:
# X_train:  (369, 256, 256, 1)
# y_train:  (369, 256, 256, 1)
# X_val:  (159, 256, 256, 1)
# y_val:  (159, 256, 256, 1)
# X_test:  (132, 256, 256, 1)
# y_test:  (132, 256, 256, 1)

# %%
# TODO: Why do we call train_test_split twice?
# TODO: YOUR_ANSWER
"""In order to have more training data than testing and validation data, we utilized two different calls. During the first call, we designated the dataset as testing data and during the second call, we designated it as validation data. This allowed us to increase the amount of training data available for our purposes."""
# Out:
# 'In order to have more training data than testing and validation data, we utilized two different calls. During the first call, we designated the dataset as testing data and during the second call, we designated it as validation data. This allowed us to increase the amount of training data available for our purposes.'

# %%
#
# We will use keras_unet's built-in data augmentation
# functionality.
#
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    X_train, y_train, batch_size=2,
    data_gen_args = dict(
        rotation_range=15.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=50,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='constant'
    ))

# %%
# TODO: Please explain the code from above.
# TODO: YOUR_ANSWER

"""The function get_augmented is utilized to produce additional image data with various transformations to train a machine learning model. It requires the training data X_train and their corresponding labels y_train, as well as a batch size of 2 and a dictionary containing data augmentation arguments. These arguments determine the extent of random modifications that can be applied to the images to expand the training data. For example, rotation_range=15. specifies that the images can be rotated randomly by up to 15 degrees, while width_shift_range and height_shift_range determine the range of horizontal and vertical shifts. The shear_range, zoom_range, horizontal_flip, and vertical_flip parameters control the range of random shearing, zooming, and flipping of the images. Finally, fill_mode='constant' indicates how to fill the empty pixels produced by these transformations."""
# Out:
# "The function get_augmented is utilized to produce additional image data with various transformations to train a machine learning model. It requires the training data X_train and their corresponding labels y_train, as well as a batch size of 2 and a dictionary containing data augmentation arguments. These arguments determine the extent of random modifications that can be applied to the images to expand the training data. For example, rotation_range=15. specifies that the images can be rotated randomly by up to 15 degrees, while width_shift_range and height_shift_range determine the range of horizontal and vertical shifts. The shear_range, zoom_range, horizontal_flip, and vertical_flip parameters control the range of random shearing, zooming, and flipping of the images. Finally, fill_mode='constant' indicates how to fill the empty pixels produced by these transformations."

# %%
# Run the following code to visualize augmented examples.
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=xx, mask_imgs=yy, nm_img_to_plot=2, figsize=6)
# Out:
# (2, 256, 256, 1) (2, 256, 256, 1)

# %%
#
# Now, we set up a U-Net classifier.
#
from keras_unet.models import custom_unet

model = custom_unet(
    X_train[0].shape,
    use_batch_norm=False,
    num_classes=1,
    filters=64,
    dropout=0.2,
    output_activation='sigmoid'
)

# %%
# TODO: How many  trainable parameters does the model use?
# TODO: YOUR_ANSWER
print (model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 256, 256, 1  0           []
#                                 )]
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  640         ['input_2[0][0]']
#                                 )
#
#  spatial_dropout2d_5 (SpatialDr  (None, 256, 256, 64  0          ['conv2d_19[0][0]']
#  opout2D)                       )
#
#  conv2d_20 (Conv2D)             (None, 256, 256, 64  36928       ['spatial_dropout2d_5[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_20[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_4[0][0]']
#                                 8)
#
#  spatial_dropout2d_6 (SpatialDr  (None, 128, 128, 12  0          ['conv2d_21[0][0]']
#  opout2D)                       8)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  147584      ['spatial_dropout2d_6[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_5[0][0]']
#
#  spatial_dropout2d_7 (SpatialDr  (None, 64, 64, 256)  0          ['conv2d_23[0][0]']
#  opout2D)
#
#  conv2d_24 (Conv2D)             (None, 64, 64, 256)  590080      ['spatial_dropout2d_7[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_6[0][0]']
#
#  spatial_dropout2d_8 (SpatialDr  (None, 32, 32, 512)  0          ['conv2d_25[0][0]']
#  opout2D)
#
#  conv2d_26 (Conv2D)             (None, 32, 32, 512)  2359808     ['spatial_dropout2d_8[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 512)  0          ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 16, 16, 1024  4719616     ['max_pooling2d_7[0][0]']
#                                 )
#
#  spatial_dropout2d_9 (SpatialDr  (None, 16, 16, 1024  0          ['conv2d_27[0][0]']
#  opout2D)                       )
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 1024  9438208     ['spatial_dropout2d_9[0][0]']
#                                 )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 512)  2097664    ['conv2d_28[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 32, 32, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'conv2d_26[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_4[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 32, 32, 512)  2359808     ['conv2d_29[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 64, 64, 256)  524544     ['conv2d_30[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 64, 64, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_24[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_5[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 256)  590080      ['conv2d_31[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 128, 128, 12  131200     ['conv2d_32[0][0]']
#  spose)                         8)
#
#  concatenate_6 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_transpose_6[0][0]',
#                                 6)                                'conv2d_22[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_6[0][0]']
#                                 8)
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 12  147584      ['conv2d_33[0][0]']
#                                 8)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 64  32832      ['conv2d_34[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'conv2d_20[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 64  36928       ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 1)  65          ['conv2d_36[0][0]']
#
# ==================================================================================================
# Total params: 31,030,593
# Trainable params: 31,030,593
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
#
# Let's compile the model. Please use a LEARNING_RATE of 0.01
# and a MOMENTUM of 0.99.
#
LEARNING_RATE = 0.01
MOMENTUM = 0.99

# %%
#
# We will use Stochastic Gradient Descent as optimizer
# and use IoU as a metric.
#
from keras.optimizers import SGD
from keras_unet.metrics import iou, iou_thresholded

model.compile(
    optimizer=SGD(learning_rate=LEARNING_RATE, momentum=MOMENTUM),
    loss='binary_crossentropy',
    metrics=[iou, iou_thresholded]
)

# %%
# TODO: Please explain Intersect-over-Union (IoU) in just a few sentences.
# TODO: YOUR_ANSWER

"""The Intersection-over-Union (IoU) metric is widely utilized to assess the similarity between two bounding boxes. It is obtained by dividing the area of intersection between the two boxes by the area of their union. A greater IoU value indicates that the two boxes have a larger overlap and are more similar."""
# Out:
# 'The Intersection-over-Union (IoU) metric is widely utilized to assess the similarity between two bounding boxes. It is obtained by dividing the area of intersection between the two boxes by the area of their union. A greater IoU value indicates that the two boxes have a larger overlap and are more similar.'

# %%
#
# Now let's train the model for 30 epochs!
#
# TODO: Please complete the code below.
# Hint: Don't forget to use the train_gen from above as training data.
# Hint 2: Please don't forget (X_val, y_val) as validation data.
# Hint 3: steps_per_epoch should be set to all of the X_train.
# Hint 4: This will take roughly 30 minutes.
# Hint 5: If you are stuck, look through the repo of keras_unet!
#
history = model.fit(
                    train_gen,
                    steps_per_epoch=len(X_train) // 2,
                    epochs=30,
                    validation_data=(X_val, y_val)                    
)
# Out:
# Epoch 1/30
# 184/184 [==============================] - 6s 23ms/step - loss: 0.2511 - iou: 0.0454 - iou_thresholded: 2.4888e-04 - val_loss: 0.2493 - val_iou: 0.0787 - val_iou_thresholded: 6.0699e-06
# Epoch 2/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1886 - iou: 0.0967 - iou_thresholded: 1.4428e-04 - val_loss: 0.2091 - val_iou: 0.1136 - val_iou_thresholded: 6.0699e-06
# Epoch 3/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1689 - iou: 0.1378 - iou_thresholded: 1.6686e-04 - val_loss: 0.2072 - val_iou: 0.1206 - val_iou_thresholded: 6.0699e-06
# Epoch 4/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1736 - iou: 0.1389 - iou_thresholded: 0.0253 - val_loss: 0.2025 - val_iou: 0.1079 - val_iou_thresholded: 6.0699e-06
# Epoch 5/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1820 - iou: 0.1126 - iou_thresholded: 0.0232 - val_loss: 0.2459 - val_iou: 0.0635 - val_iou_thresholded: 6.0699e-06
# Epoch 6/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1796 - iou: 0.1149 - iou_thresholded: 1.4419e-04 - val_loss: 0.2304 - val_iou: 0.1400 - val_iou_thresholded: 6.0699e-06
# Epoch 7/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1764 - iou: 0.1228 - iou_thresholded: 1.4301e-04 - val_loss: 0.1754 - val_iou: 0.1629 - val_iou_thresholded: 6.0699e-06
# Epoch 8/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1532 - iou: 0.1789 - iou_thresholded: 0.0675 - val_loss: 0.1503 - val_iou: 0.2517 - val_iou_thresholded: 0.4521
# Epoch 9/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1384 - iou: 0.2435 - iou_thresholded: 0.3080 - val_loss: 0.1356 - val_iou: 0.2783 - val_iou_thresholded: 0.2749
# Epoch 10/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.1105 - iou: 0.3124 - iou_thresholded: 0.3730 - val_loss: 0.1080 - val_iou: 0.4996 - val_iou_thresholded: 0.5835
# Epoch 11/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.0992 - iou: 0.3697 - iou_thresholded: 0.4300 - val_loss: 0.0837 - val_iou: 0.5270 - val_iou_thresholded: 0.6591
# Epoch 12/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0822 - iou: 0.4545 - iou_thresholded: 0.5745 - val_loss: 0.0628 - val_iou: 0.6431 - val_iou_thresholded: 0.7192
# Epoch 13/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0730 - iou: 0.5070 - iou_thresholded: 0.6162 - val_loss: 0.0625 - val_iou: 0.6156 - val_iou_thresholded: 0.7299
# Epoch 14/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0668 - iou: 0.5338 - iou_thresholded: 0.6441 - val_loss: 0.0551 - val_iou: 0.6431 - val_iou_thresholded: 0.7582
# Epoch 15/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0663 - iou: 0.5322 - iou_thresholded: 0.6527 - val_loss: 0.0555 - val_iou: 0.6424 - val_iou_thresholded: 0.7730
# Epoch 16/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0564 - iou: 0.5949 - iou_thresholded: 0.6993 - val_loss: 0.0500 - val_iou: 0.6600 - val_iou_thresholded: 0.7990
# Epoch 17/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0614 - iou: 0.5541 - iou_thresholded: 0.6709 - val_loss: 0.0554 - val_iou: 0.6566 - val_iou_thresholded: 0.7612
# Epoch 18/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0577 - iou: 0.5961 - iou_thresholded: 0.6949 - val_loss: 0.0472 - val_iou: 0.6591 - val_iou_thresholded: 0.8074
# Epoch 19/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0492 - iou: 0.6263 - iou_thresholded: 0.7284 - val_loss: 0.0394 - val_iou: 0.7346 - val_iou_thresholded: 0.8278
# Epoch 20/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0434 - iou: 0.6827 - iou_thresholded: 0.7708 - val_loss: 0.0390 - val_iou: 0.7789 - val_iou_thresholded: 0.8323
# Epoch 21/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.0437 - iou: 0.6636 - iou_thresholded: 0.7601 - val_loss: 0.0583 - val_iou: 0.6515 - val_iou_thresholded: 0.7553
# Epoch 22/30
# 184/184 [==============================] - 4s 21ms/step - loss: 0.0442 - iou: 0.6710 - iou_thresholded: 0.7660 - val_loss: 0.0365 - val_iou: 0.7467 - val_iou_thresholded: 0.8442
# Epoch 23/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0439 - iou: 0.6658 - iou_thresholded: 0.7566 - val_loss: 0.0399 - val_iou: 0.7635 - val_iou_thresholded: 0.8279
# Epoch 24/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0477 - iou: 0.6464 - iou_thresholded: 0.7372 - val_loss: 0.0404 - val_iou: 0.7237 - val_iou_thresholded: 0.8325
# Epoch 25/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0410 - iou: 0.6804 - iou_thresholded: 0.7695 - val_loss: 0.0366 - val_iou: 0.7668 - val_iou_thresholded: 0.8376
# Epoch 26/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0415 - iou: 0.6899 - iou_thresholded: 0.7726 - val_loss: 0.0538 - val_iou: 0.6869 - val_iou_thresholded: 0.7865
# Epoch 27/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0443 - iou: 0.6718 - iou_thresholded: 0.7669 - val_loss: 0.0391 - val_iou: 0.7294 - val_iou_thresholded: 0.8367
# Epoch 28/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0390 - iou: 0.6878 - iou_thresholded: 0.7764 - val_loss: 0.0366 - val_iou: 0.7341 - val_iou_thresholded: 0.8529
# Epoch 29/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0417 - iou: 0.7114 - iou_thresholded: 0.7887 - val_loss: 0.0348 - val_iou: 0.7819 - val_iou_thresholded: 0.8430
# Epoch 30/30
# 184/184 [==============================] - 4s 20ms/step - loss: 0.0397 - iou: 0.6865 - iou_thresholded: 0.7768 - val_loss: 0.0356 - val_iou: 0.7653 - val_iou_thresholded: 0.8469

# %%
# We can use keras_unet functionality to visualize metrics and loss during training.
from keras_unet.utils import plot_segm_history

plot_segm_history(history)

# %%
# TODO: Do these plots look good to you?
# TODO: YOUR_ANSWER

"""Yes, the plots are good."""
# Out:
# 'Yes, the plots are good.'

# %% [markdown]
# ## 3. Evaluate U-Net (10 points)

# %%
# Let's predict all of X_test
y_pred = model.predict(X_test)
# Out:
# 5/5 [==============================] - 0s 53ms/step

# %%
# ...and look at some results.
plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-15b1c4294275> in <cell line: 2>()
#       1 # ...and look at some results.
# ----> 2 plot_imgs(org_imgs=X_test, mask_imgs=y_test, pred_imgs=y_pred, nm_img_to_plot=9)
#
# NameError: name 'plot_imgs' is not defined

# %%
import sklearn.metrics

# %%
# Let's use the Jaccard score to compare a thresholded
# y_pred to the groundtruth y_test.
sklearn.metrics.jaccard_score(y_test.ravel(), (y_pred > 0.5).ravel())
# Out:
# 0.8419175769966836

# %%
# TODO: What is the difference between Jaccard Score and Intersect-over-Union from above?
# TODO: YOUR_ANSWER 
"""The Jaccard score and IoU are equivalent measures that are used to evaluate the similarity between two sets, or in the case of object detection, the similarity between two bounding boxes. Both metrics calculate the ratio of the size of the intersection between two sets (or boxes) to the size of their union."""
# Out:
# 'The Jaccard score and IoU are equivalent measures that are used to evaluate the similarity between two sets, or in the case of object detection, the similarity between two bounding boxes. Both metrics calculate the ratio of the size of the intersection between two sets (or boxes) to the size of their union.'

# %%
# TODO: Did the U-Net perform well on X_test?
# TODO: YOUR_ANSWER

"""Yes"""
# Out:
# 'Yes'

# %% [markdown]
# ## 4. Combine U-Net with SAM (10 points)

# %%
# Instead of running SAM in auto mode without seeds (Task 1), we will now
# use the U-Net predictions on X_test to seed the SAM model.

# %%
# We can use the following convenience functions
# to 1) convert mahotas bounding boxes to SAM format
# and 2) combine the SAM output tensors to a mask.

# %%
def mahotas_bbox_to_sam(bbs):

  new_bbs = []

  for i,bb in enumerate(bbs):
    # from (y1, y2, x1, x2)
    # to (x1, y1, x2, y2)
    if i == 0:
      continue
    new_bb = [bb[2], bb[0], bb[3], bb[1]]
    new_bbs.append(new_bb)

  return new_bbs

# %%
def sam_to_mask(results):

  results = results.cpu() # copy back to cpu land

  mask = np.array(results[0,0])

  for s in results:
    mask[s[0] == 1] = 1

  return mask

# %%
# The following code combines the U-Net predictions with SAM.
#
# TODO: Please study the code and answer the TODOs in-line.

# %%
y_pred_sam = y_pred.copy()
y_pred_sam[:] = 0

for z,img in enumerate(X_test):

  # TODO: EXPLAIN CODE BELOW
  mh.imsave('test.png', (img[:,:,0]*255).astype(np.uint8))
  #saves an image as test.png it also creates the scaling of values from 0-255


  # TODO: EXPLAIN CODE BELOW
  pred = (y_pred[z] > 0.5)
  #connected component labeling to the binary mask 'pred'


  # TODO: EXPLAIN CODE BELOW
  pred, _ = mh.labeled.label(pred)
   #Here the thereshold values are being modified,

  # TODO: EXPLAIN CODE BELOW
  bbs = mh.labeled.bbox(pred)
  #calculates the bounding boxes of each connected component in the label matrix pred. 



  # TODO: EXPLAIN CODE BELOW
  bbs_converted = mahotas_bbox_to_sam(bbs)
  #converts the bounding box coordinates from the format used by the Mahotas library

  # TODO: EXPLAIN CODE BELOW
  results = SegManualMaskPredictor().image_predict(
      source="test.png",
      model_type="vit_l", # vit_l, vit_h, vit_b
      input_box=bbs_converted, 
      multimask_output=False,
      random_color=False,
      show=False,
      save=False,
  )
  ##Here we are runnin the sam in manual prediction, with no random colors and model type vit_l 


  # TODO: EXPLAIN CODE BELOW
  sam_and_unet_pred = sam_to_mask(results)
  #converts the segmentation masks returned by the SAM tool (results)

  # TODO: EXPLAIN CODE BELOW
  y_pred_sam[z,:,:,0] = sam_and_unet_pred
  # updates the predicted output y_pred_sam at slice z with the segmentation masks predicted by the SAM tool
# Out:
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.

# %% [markdown]
# ## 5. Compare U-Net vs. U-Net+SAM. (10 points)

# %%
# U-Net performance on X_test (from Task 3)
sklearn.metrics.jaccard_score(y_test.ravel(), (y_pred > 0.5).ravel())
# Out:
# 0.8419175769966836

# %%
# U-Net + SAM performance on X_test
sklearn.metrics.jaccard_score(y_test.ravel(), y_pred_sam.ravel())
# Out:
# 0.8344435793595919

# %%
# TODO: Please explain the results - is U-Net+SAM a good addition?
# TODO: YOUR_ANSWER
"""U-net performs better compared to the SAM + UNET"""

# %% [markdown]
# ## Bonus: Improve the results. (33 points)

# %%
# Please improve the results of U-Net+SAM and show the improved Jaccard score.

# %%
# TODO: YOUR_CODE
y_pred_sam = y_pred.copy()
y_pred_sam[:] = 0

for z,img in enumerate(X_test):

  # TODO: EXPLAIN CODE BELOW
  mh.imsave('test.png', (img[:,:,0]*255).astype(np.uint8))
  #saves an image as test.png it also creates the scaling of values from 0-255


  # TODO: EXPLAIN CODE BELOW
  pred = (y_pred[z] > 0.6)
  #connected component labeling to the binary mask 'pred'


  # TODO: EXPLAIN CODE BELOW
  pred, _ = mh.labeled.label(pred)
   #Here the thereshold values are being modified,

  # TODO: EXPLAIN CODE BELOW
  bbs = mh.labeled.bbox(pred)
  #calculates the bounding boxes of each connected component in the label matrix pred. 



  # TODO: EXPLAIN CODE BELOW
  bbs_converted = mahotas_bbox_to_sam(bbs)
  #converts the bounding box coordinates from the format used by the Mahotas library

  # TODO: EXPLAIN CODE BELOW
  results = SegManualMaskPredictor().image_predict(
      source="test.png",
      model_type="vit_l", # vit_l, vit_h, vit_b
      input_box=bbs_converted, 
      multimask_output=False,
      random_color=False,
      show=False,
      save=False,
  )
  ##Here we are runnin the sam in manual prediction, with no random colors and model type vit_l 


  # TODO: EXPLAIN CODE BELOW
  sam_and_unet_pred = sam_to_mask(results)
  #converts the segmentation masks returned by the SAM tool (results)

  # TODO: EXPLAIN CODE BELOW
  y_pred_sam[z,:,:,0] = sam_and_unet_pred
  # updates the predicted output y_pred_sam at slice z with the segmentation masks predicted by the SAM tool
# Out:
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.
# vit_l model already exists as 'vit_l.pth'. Skipping download.

# %%
sklearn.metrics.jaccard_score(y_test.ravel(), (y_pred > 0.7).ravel())
# Out:
# 0.8375329560022253

# %%
sklearn.metrics.jaccard_score(y_test.ravel(), y_pred_sam.ravel())
# Out:
# 0.8408011177017037

# %%
"""The imporvement is noticeable"""

# %%
#In colab with Sruthi Chirumamilla

# %%
#
# You made it!!
#
#                 _ ___                /^^\ /^\  /^^\_
#     _          _@)@) \            ,,/ '` ~ `'~~ ', `\.
#   _/o\_ _ _ _/~`.`...'~\        ./~~..,'`','',.,' '  ~:
#  / `,'.~,~.~  .   , . , ~|,   ,/ .,' , ,. .. ,,.   `,  ~\_
# ( ' _' _ '_` _  '  .    , `\_/ .' ..' '  `  `   `..  `,   \_
#  ~V~ V~ V~ V~ ~\ `   ' .  '    , ' .,.,''`.,.''`.,.``. ',   \_
#   _/\ /\ /\ /\_/, . ' ,   `_/~\_ .' .,. ,, , _/~\_ `. `. '.,  \_
#  < ~ ~ '~`'~'`, .,  .   `_: ::: \_ '      `_/ ::: \_ `.,' . ',  \_
#   \ ' `_  '`_    _    ',/ _::_::_ \ _    _/ _::_::_ \   `.,'.,`., \-,-,-,_,_,
#    `'~~ `'~~ `'~~ `'~~  \(_)(_)(_)/  `~~' \(_)(_)(_)/ ~'`\_.._,._,'_;_;_;_;_;
#
